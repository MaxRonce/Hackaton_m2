# %%
import numpy as np
import random

# %%
# generate 59064 rand 0 and 1 data written on each raw
# Make the first raw 42 

file = open("test.txt", "w")
file.write("42\n")

for i in range(59064):
    num = np.random.randint(0, 2, size=1)
    # avoid [1] bracket around
    file.write(str(num[0]))
    file.write("\n")

file.close()
